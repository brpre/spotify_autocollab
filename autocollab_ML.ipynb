# %%
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KDTree
import numpy as np
from sklearn.decomposition import PCA

# %%
# list of audio features that we want to use for analysis
features_list = ['acousticness', 'danceability', 'energy', 
                 'instrumentalness', 'liveness', 'loudness', 
                 'speechiness', 'tempo', 'valence']

# %% [markdown]
# ### Load data from saved CSVs

# %%
# get combined song data from all users except eddie, so we can recommend songs for eddie
df_agg_full = pd.read_csv('aggragated_df.csv')

df_agg_full.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  acousticness  \
# 0           0             0      0.513000
# 1           1             1      0.000197
# 2           2             2      0.010800
# 3           3             3      0.065900
# 4           4             4      0.027100
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/1db6...         0.712
# 1  https://api.spotify.com/v1/audio-analysis/786N...         0.588
# 2  https://api.spotify.com/v1/audio-analysis/4qg2...         0.453
# 3  https://api.spotify.com/v1/audio-analysis/5Clq...         0.470
# 4  https://api.spotify.com/v1/audio-analysis/1Mbo...         0.719
#
#    duration_ms  energy                      id  instrumentalness  key  \
# 0     199880.0   0.497  1db6ixe9nX6cqt2V1DYZnW          0.000003  4.0
# 1     295187.0   0.825  786NsUYn4GGUf8AOt0SQhP          0.001380  4.0
# 2     257587.0   0.906  4qg2rXtE20scfPhGvG5tqq          0.000000  2.0
# 3     205442.0   0.696  5ClqcvP4dYDDX6Zv3jPQD1          0.000039  9.0
# 4     157215.0   0.707  1MboFNLuzrmG98WWcoam6B          0.008650  9.0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0    0.3030    -7.943   1.0       0.0639   93.953             4.0
# 1    0.0885    -5.882   1.0       0.0328  129.968             4.0
# 2    0.6570    -3.606   1.0       0.0640  146.960             4.0
# 3    0.0962    -4.749   1.0       0.1040  169.976             4.0
# 4    0.1480    -8.217   1.0       0.2660  197.942             4.0
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/1db6ixe9nX6c...  audio_features
# 1  https://api.spotify.com/v1/tracks/786NsUYn4GGU...  audio_features
# 2  https://api.spotify.com/v1/tracks/4qg2rXtE20sc...  audio_features
# 3  https://api.spotify.com/v1/tracks/5ClqcvP4dYDD...  audio_features
# 4  https://api.spotify.com/v1/tracks/1MboFNLuzrmG...  audio_features
#
#                                     uri  valence
# 0  spotify:track:1db6ixe9nX6cqt2V1DYZnW    0.457
# 1  spotify:track:786NsUYn4GGUf8AOt0SQhP    0.397
# 2  spotify:track:4qg2rXtE20scfPhGvG5tqq    0.361
# 3  spotify:track:5ClqcvP4dYDDX6Zv3jPQD1    0.802
# 4  spotify:track:1MboFNLuzrmG98WWcoam6B    0.071

# %%
df_agg = df_agg_full.loc[:, features_list].drop_duplicates()

df_agg.head()
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0      0.513000         0.712   0.497          0.000003    0.3030    -7.943
# 1      0.000197         0.588   0.825          0.001380    0.0885    -5.882
# 2      0.010800         0.453   0.906          0.000000    0.6570    -3.606
# 3      0.065900         0.470   0.696          0.000039    0.0962    -4.749
# 4      0.027100         0.719   0.707          0.008650    0.1480    -8.217
#
#    speechiness    tempo  valence
# 0       0.0639   93.953    0.457
# 1       0.0328  129.968    0.397
# 2       0.0640  146.960    0.361
# 3       0.1040  169.976    0.802
# 4       0.2660  197.942    0.071

# %%
# get eddie's song data
df_eddie_full = pd.read_csv('eddie_song_data.csv')

df_eddie_full.head()
# Out:
#    Unnamed: 0  acousticness  \
# 0           0         0.192
# 1           1         0.194
# 2           2         0.339
# 3           3         0.634
# 4           4         0.231
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/20Mu...         0.741
# 1  https://api.spotify.com/v1/audio-analysis/4S7Y...         0.598
# 2  https://api.spotify.com/v1/audio-analysis/3F1g...         0.422
# 3  https://api.spotify.com/v1/audio-analysis/71Aa...         0.450
# 4  https://api.spotify.com/v1/audio-analysis/4Q34...         0.647
#
#    duration_ms  energy                      id  instrumentalness   key  \
# 0     231964.0   0.645  20MuVazoNMv6xjKPnRFOxG          0.000000  11.0
# 1     238307.0   0.252  4S7YHmlWwfwArgd8LfSPud          0.133000   2.0
# 2     225780.0   0.349  3F1gjSkTX9kvxOo6BnlRNd          0.000240   4.0
# 3     160160.0   0.300  71AaGUlQ7I5dRgDEQpdnI4          0.000003   7.0
# 4     193839.0   0.667  4Q34FP1AT7GEl9oLgNtiWj          0.000000   5.0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0    0.1630    -5.116   0.0       0.0963  149.070             4.0
# 1    0.0992   -15.086   1.0       0.0644  120.064             4.0
# 2    0.1080   -12.424   0.0       0.3150   57.000             4.0
# 3    0.1420    -9.530   1.0       0.0477   96.394             4.0
# 4    0.1330    -5.563   1.0       0.3040  172.080             4.0
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/20MuVazoNMv6...  audio_features
# 1  https://api.spotify.com/v1/tracks/4S7YHmlWwfwA...  audio_features
# 2  https://api.spotify.com/v1/tracks/3F1gjSkTX9kv...  audio_features
# 3  https://api.spotify.com/v1/tracks/71AaGUlQ7I5d...  audio_features
# 4  https://api.spotify.com/v1/tracks/4Q34FP1AT7GE...  audio_features
#
#                                     uri  valence
# 0  spotify:track:20MuVazoNMv6xjKPnRFOxG   0.4880
# 1  spotify:track:4S7YHmlWwfwArgd8LfSPud   0.0352
# 2  spotify:track:3F1gjSkTX9kvxOo6BnlRNd   0.1340
# 3  spotify:track:71AaGUlQ7I5dRgDEQpdnI4   0.2070
# 4  spotify:track:4Q34FP1AT7GEl9oLgNtiWj   0.7040

# %%
df_eddie = df_eddie_full.loc[:, features_list]

df_eddie.head()
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0         0.192         0.741   0.645          0.000000    0.1630    -5.116
# 1         0.194         0.598   0.252          0.133000    0.0992   -15.086
# 2         0.339         0.422   0.349          0.000240    0.1080   -12.424
# 3         0.634         0.450   0.300          0.000003    0.1420    -9.530
# 4         0.231         0.647   0.667          0.000000    0.1330    -5.563
#
#    speechiness    tempo  valence
# 0       0.0963  149.070   0.4880
# 1       0.0644  120.064   0.0352
# 2       0.3150   57.000   0.1340
# 3       0.0477   96.394   0.2070
# 4       0.3040  172.080   0.7040

# %% [markdown]
# # Apply PCA on both DFs

# %%
# Fit transform on df agg. Transform on eddie

# apply principle component analysis to eddie's df and aggregate df
pca = PCA(whiten=True)
agg_prime = pca.fit_transform(df_agg)

agg_prime
# Out:
# array([[-0.76705672, -0.38412263, -0.44664296, ...,  1.11315152,
#          0.10644264, -0.72005354],
#        [ 0.43868657, -0.69550279,  0.61206556, ..., -0.74489819,
#         -0.88546393, -0.93676926],
#        [ 1.00825486, -1.11004238,  0.1395863 , ...,  0.93556969,
#          0.08870582, -1.11984004],
#        ...,
#        [-0.39774618, -1.34967589, -0.37817773, ...,  0.07516869,
#         -1.90588131, -1.13035191],
#        [ 0.1029104 , -0.65558931, -0.67724614, ..., -0.03203128,
#         -1.36374928, -1.08411212],
#        [ 0.50363694,  0.04960464, -1.19725414, ...,  0.35602184,
#         -0.50843834, -0.73538071]])

# %%
eddie_prime = pca.transform(df_eddie)

eddie_prime
# Out:
# array([[ 1.07799785, -0.78757567,  0.01776087, ...,  0.73241514,
#          0.01490478, -0.31626393],
#        [ 0.10241051,  1.18455631,  0.66868706, ...,  0.78611108,
#          0.3983179 , -0.45897346],
#        [-2.00545889,  0.42055686,  0.06264548, ..., -0.28332496,
#         -0.08362978,  2.70024966],
#        ...,
#        [-1.26060764,  0.56698648,  0.6660888 , ..., -0.27087365,
#         -0.2048661 , -0.67489325],
#        [-0.87532195, -0.66620567, -1.69762367, ...,  0.82153666,
#          0.02249762,  3.28112996],
#        [-0.89668714, -1.44902872, -0.26534115, ...,  0.75128461,
#          0.30289888,  0.28068498]])

# %% [markdown]
# ### Choosing a K

# %%
from sklearn.cluster import KMeans
 
x = eddie_prime

mean_d_dict = dict()
for n_clusters in range(2, 10):

    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(x)
    y = kmeans.predict(x)

    plt.figure()
    sns.scatterplot(x=x[:, 0], y=x[:, 1], s=100, hue=y, palette='Set2')
    
    # compute & store mean distance
    mean_d = -kmeans.score(x)
    mean_d_dict[n_clusters] = mean_d
    
    plt.suptitle(f'{n_clusters} clusters has mean_d: {mean_d:.1e}')
    
    plt.gca().get_legend().remove()
    plt.gcf().set_size_inches(6, 3)

# %% [markdown]
# Note that our data has 9 dimensions, making it difficult to represent visually above. We'll quantify separation later.

# %%
mean_d_dict
# Out:
# {2: 1780.884352661536,
#  3: 1603.258360778769,
#  4: 1460.722922374618,
#  5: 1356.5259260759594,
#  6: 1278.7476902701187,
#  7: 1220.2612093473729,
#  8: 1170.0934502327802,
#  9: 1119.6444294844664}

# %%
plt.plot(list(mean_d_dict.keys()), list(mean_d_dict.values()))
plt.xlabel('number of clusters')
plt.ylabel('mean dist^2 to centroid')
# Out:
# Text(0, 0.5, 'mean dist^2 to centroid')

# %% [markdown]
# 5 clusters is our best number based on the above plot, so we used 5 clusters below.

# %%
n_clusters = 5

kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(x)
y = kmeans.predict(x)

# %%
# these centroids represent the clustered data from eddie_df
centroids = kmeans.cluster_centers_

centroids
# Out:
# array([[ 0.339101  , -0.4465599 ,  0.20258149, -0.26983642, -1.12945647,
#         -1.03106017,  0.97029071, -0.42838579, -0.10704062],
#        [-0.16242565, -0.612816  , -0.06065886, -0.29186632,  0.7355431 ,
#         -0.64331946,  0.35898097,  0.00497245, -0.00273076],
#        [ 0.52159281, -0.5049504 ,  0.74553018, -0.27999523, -0.29736057,
#          1.27042612,  1.53035996,  0.38909206,  0.2586405 ],
#        [ 1.18084888, -0.34908654,  0.33965695, -0.40144815, -0.08358982,
#         -0.35439317,  1.16837138, -0.49308618,  2.36989688],
#        [-0.93314771, -0.71343968,  0.03640383, -0.24645489, -0.36103856,
#         -0.1985984 ,  0.52666018, -0.83936717,  2.19688552]])

# %% [markdown]
# ## Cluster visualization

# %%
# code modified from https://stackoverflow.com/questions/32008994/seaborn-scatterplot-matrix-adding-extra-points-with-custom-styles

# add the centroids to a dataframe as rows
centroids_df = pd.DataFrame(centroids, columns=features_list)
# add a column labeling the centroids
centroids_df['cluster'] = 'centroid'

centroids_df
# Out:
#    acousticness  danceability    energy  instrumentalness  liveness  loudness  \
# 0      0.339101     -0.446560  0.202581         -0.269836 -1.129456 -1.031060
# 1     -0.162426     -0.612816 -0.060659         -0.291866  0.735543 -0.643319
# 2      0.521593     -0.504950  0.745530         -0.279995 -0.297361  1.270426
# 3      1.180849     -0.349087  0.339657         -0.401448 -0.083590 -0.354393
# 4     -0.933148     -0.713440  0.036404         -0.246455 -0.361039 -0.198598
#
#    speechiness     tempo   valence   cluster
# 0     0.970291 -0.428386 -0.107041  centroid
# 1     0.358981  0.004972 -0.002731  centroid
# 2     1.530360  0.389092  0.258640  centroid
# 3     1.168371 -0.493086  2.369897  centroid
# 4     0.526660 -0.839367  2.196886  centroid

# %%
# extend eddie's dataframe to include labels
df_eddie_ext = pd.DataFrame(eddie_prime, columns=features_list)

# combine predictions and eddie into one dataframe
df_eddie_ext['cluster'] = y

df_eddie_ext
# Out:
#      acousticness  danceability    energy  instrumentalness  liveness  \
# 0        1.077998     -0.787576  0.017761         -0.163018 -0.131721
# 1        0.102411      1.184556  0.668687         -0.636691 -2.192724
# 2       -2.005459      0.420557  0.062645         -0.799864 -1.673413
# 3       -0.686285     -0.043189 -1.312524         -0.638141 -0.564152
# 4        1.847381     -0.617975  0.302380         -0.250116  0.586193
# ..            ...           ...       ...               ...       ...
# 288      0.439406     -0.832389 -0.429787         -0.325486  1.660304
# 289      1.105613     -0.702896 -0.512613         -0.261547  1.292774
# 290     -1.260608      0.566986  0.666089         -0.974854  0.559171
# 291     -0.875322     -0.666206 -1.697624         -0.600134  1.962943
# 292     -0.896687     -1.449029 -0.265341          0.095721 -0.548439
#
#      loudness  speechiness     tempo   valence  cluster
# 0   -0.745261     0.732415  0.014905 -0.316264        0
# 1   -1.195034     0.786111  0.398318 -0.458973        0
# 2   -0.229678    -0.283325 -0.083630  2.700250        4
# 3   -0.282734    -0.174446  0.961443  0.008614        1
# 4   -0.355588     0.110032 -0.002725  2.304540        3
# ..        ...          ...       ...       ...      ...
# 288 -0.840318    -0.309242  1.369540  0.377395        1
# 289  0.096393    -0.173360 -0.756666  1.653210        3
# 290 -0.405272    -0.270874 -0.204866 -0.674893        1
# 291  0.253894     0.821537  0.022498  3.281130        4
# 292 -1.466658     0.751285  0.302899  0.280685        1
#
# [293 rows x 10 columns]

# %%
# combine centroids and eddie into one dataframe
eddie_centrs_df = pd.concat([df_eddie_ext, centroids_df], ignore_index=True)

centr_vis = sns.PairGrid(eddie_centrs_df, hue='cluster',
                         palette='Set2',
                         hue_kws={'s': [20, 20, 20, 20, 20, 200],
                                 'marker': ['o', 'o', 'o', 'o', 'o', '*']})

centr_vis.map(plt.scatter, linewidth=1)
plt.legend(title='Labels', fontsize='25', title_fontsize='40')
centr_vis.fig.suptitle('Paired Audio Features with Clusters', y=1.1, fontsize = 40)
centr_vis.fig.set_size_inches(20, 20)

# %%
centr_vis.savefig('cluster_pairgrid.pdf')

# %% [markdown]
# The centroids we got are a coarse representation of user preference.
#
# Now, we loop over the centroids and get k nearest for each. We treat the centroids as "query embeddings" in an embedding space of possible recommendations, and recommend the items that are closest to each query embedding.

# %%
import collections

# init a KD Tree that we can query to find the nearest neighbors 
kdt = KDTree(agg_prime, leaf_size=30, metric='euclidean')

rec_indices = list()

# for each centroid, get k nearest
for centroid in centroids:
    
    # reshape centroid
    centroid = centroid.reshape(-1,1)

    # query KDT to find indexes of nearest neighbors to our centroid
    nearest_list = kdt.query(centroid.T, k=10, return_distance=False)
    
    # add items that haven't already been recommended
    
    for idx in nearest_list.flatten():
        rec_indices.append(idx)

len(rec_indices)
# Out:
# 50

# %% [markdown]
# Now we can see the 10 candidates closest to each query embedding. It doesn't look like much, so we'll get the corresponding songs.

# %%
# get the rows from df_agg corresponding to the indices we found
df_nearest = df_agg_full.iloc[rec_indices, :]

df_nearest
# Out:
#       Unnamed: 0  Unnamed: 0.1  acousticness  \
# 624          624           624      0.762000
# 1269         232           232      0.131000
# 1021         184           184      0.234000
# 1075          38            38      0.652000
# 839            2             2      0.000659
# 871           34            34      0.240000
# 1024         187           187      0.054600
# 386          386           386      0.178000
# 356          356           356      0.691000
# 1683         646           646      0.825000
# 342          342           342      0.631000
# 1663         626           626      0.194000
# 275          275           275      0.361000
# 636          636           636      0.063800
# 842            5             5      0.000669
# 980          143           143      0.098500
# 1557         520           520      0.311000
# 1267         230           230      0.048400
# 2011         974           974      0.797000
# 1111          74            74      0.002250
# 1563         526           526      0.719000
# 1690         653           653      0.010700
# 1361         324           324      0.288000
# 1390         353           353      0.266000
# 2163        1126          1126      0.671000
# 1372         335           335      0.225000
# 1673         636           636      0.310000
# 1243         206           206      0.879000
# 648          648           648      0.635000
# 1482         445           445      0.196000
# 297          297           297      0.070100
# 1262         225           225      0.454000
# 872           35            35      0.124000
# 865           28            28      0.038200
# 894           57            57      0.011000
# 870           33            33      0.137000
# 1236         199           199      0.453000
# 1714         677           677      0.484000
# 260          260           260      0.254000
# 1685         648           648      0.115000
# 1729         692           692      0.056700
# 1457         420           420      0.530000
# 909           72            72      0.049200
# 1459         422           422      0.040100
# 309          309           309      0.322000
# 315          315           315      0.508000
# 1262         225           225      0.454000
# 879           42            42      0.051800
# 1268         231           231      0.169000
# 1380         343           343      0.142000
#
#                                            analysis_url  danceability  \
# 624   https://api.spotify.com/v1/audio-analysis/3BXE...         0.530
# 1269  https://api.spotify.com/v1/audio-analysis/3nvR...         0.783
# 1021  https://api.spotify.com/v1/audio-analysis/2Jh3...         0.712
# 1075  https://api.spotify.com/v1/audio-analysis/6f6p...         0.282
# 839   https://api.spotify.com/v1/audio-analysis/0HJR...         0.290
# 871   https://api.spotify.com/v1/audio-analysis/7Hk6...         0.414
# 1024  https://api.spotify.com/v1/audio-analysis/3eek...         0.598
# 386   https://api.spotify.com/v1/audio-analysis/3Qeq...         0.564
# 356   https://api.spotify.com/v1/audio-analysis/3lWE...         0.616
# 1683  https://api.spotify.com/v1/audio-analysis/7ixi...         0.722
# 342   https://api.spotify.com/v1/audio-analysis/4YiK...         0.626
# 1663  https://api.spotify.com/v1/audio-analysis/1aEc...         0.693
# 275   https://api.spotify.com/v1/audio-analysis/2pfQ...         0.649
# 636   https://api.spotify.com/v1/audio-analysis/2jKc...         0.666
# 842   https://api.spotify.com/v1/audio-analysis/3YiU...         0.599
# 980   https://api.spotify.com/v1/audio-analysis/58Ta...         0.689
# 1557  https://api.spotify.com/v1/audio-analysis/1u0M...         0.855
# 1267  https://api.spotify.com/v1/audio-analysis/1zlc...         0.703
# 2011  https://api.spotify.com/v1/audio-analysis/30lY...         0.436
# 1111  https://api.spotify.com/v1/audio-analysis/5tFp...         0.531
# 1563  https://api.spotify.com/v1/audio-analysis/2zk7...         0.502
# 1690  https://api.spotify.com/v1/audio-analysis/5WKs...         0.819
# 1361  https://api.spotify.com/v1/audio-analysis/3R9N...         0.430
# 1390  https://api.spotify.com/v1/audio-analysis/0TeH...         0.685
# 2163  https://api.spotify.com/v1/audio-analysis/1y5c...         0.808
# 1372  https://api.spotify.com/v1/audio-analysis/4ZRe...         0.753
# 1673  https://api.spotify.com/v1/audio-analysis/06ib...         0.717
# 1243  https://api.spotify.com/v1/audio-analysis/69xx...         0.643
# 648   https://api.spotify.com/v1/audio-analysis/2Vji...         0.510
# 1482  https://api.spotify.com/v1/audio-analysis/4sy3...         0.654
# 297   https://api.spotify.com/v1/audio-analysis/1VjZ...         0.642
# 1262  https://api.spotify.com/v1/audio-analysis/2NCB...         0.782
# 872   https://api.spotify.com/v1/audio-analysis/0ryE...         0.483
# 865   https://api.spotify.com/v1/audio-analysis/0QwZ...         0.476
# 894   https://api.spotify.com/v1/audio-analysis/08mG...         0.310
# 870   https://api.spotify.com/v1/audio-analysis/0pKr...         0.669
# 1236  https://api.spotify.com/v1/audio-analysis/1CyA...         0.674
# 1714  https://api.spotify.com/v1/audio-analysis/6eL1...         0.898
# 260   https://api.spotify.com/v1/audio-analysis/4xyo...         0.496
# 1685  https://api.spotify.com/v1/audio-analysis/2fRo...         0.785
# 1729  https://api.spotify.com/v1/audio-analysis/6bOk...         0.458
# 980     0.1580    -4.052   0.0       0.0836  160.042             4.0
# 1557    0.0626   -10.863   1.0       0.0819  117.836             4.0
# 1267    0.6640    -6.554   1.0       0.1490   94.009             4.0
# 2011    0.1670   -13.759   1.0       0.0332   76.668             4.0
# 1111    0.0296    -6.111   0.0       0.0426   81.640             4.0
# 1563    0.6450    -9.934   1.0       0.0295   92.904             4.0
# 1690    0.1330    -7.406   0.0       0.0705  132.995             4.0
# 1361    0.1000    -7.253   0.0       0.0731  144.324             1.0
# 1390    0.0782    -7.202   1.0       0.0841  126.017             4.0
# 2163    0.1240    -8.637   0.0       0.1320   89.886             4.0
# 1372    0.1060    -5.849   0.0       0.0724  124.022             4.0
# 1673    0.1050    -8.574   0.0       0.0772   77.901             4.0
# 1243    0.1060   -26.145   0.0       0.0419  102.814             4.0
# 648     0.6130    -5.811   1.0       0.0442   94.136             4.0
# 1482    0.0999    -9.135   0.0       0.2480   95.142             4.0
# 297     0.1220    -9.686   0.0       0.1620   89.841             4.0
# 1262    0.1340    -1.458   1.0       0.0339   65.832             4.0
# 872     0.1070    -9.403   0.0       0.0272  135.175             4.0
# 865     0.0818    -9.192   1.0       0.0949   93.584             4.0
# 894     0.0828    -5.678   1.0       0.0470  188.386             4.0
# 870     0.3390    -8.322   0.0       0.0339   97.993             4.0
# 1236    0.6160    -7.150   1.0       0.0304  112.912             4.0
# 1714    0.3700    -5.707   0.0       0.3130  100.010             4.0
# 260     0.1010    -3.867   1.0       0.1030  134.900             4.0
# 1685    0.0920    -9.805   1.0       0.1150  118.931             4.0
# 1729    0.1100    -6.553   1.0       0.4870  118.227             4.0
# 1457    0.1330    -7.963   0.0       0.0407  119.985             4.0
# 909     0.0877    -3.727   1.0       0.0439  120.000             4.0
# 1459    0.0882    -9.331   1.0       0.0385  128.013             4.0
# 309     0.3400    -3.848   0.0       0.0449   74.000             4.0
# 315     0.0640    -8.302   0.0       0.0270  100.020             4.0
# 1262    0.1340    -1.458   1.0       0.0339   65.832             4.0
# 879     0.6260    -4.939   1.0       0.0355  159.779             4.0
# 1268    0.0535    -4.761   0.0       0.1360  115.034             4.0
# 1380    0.3380    -8.059   1.0       0.0863  170.027             4.0
#
#                                              track_href            type  \
# 624   https://api.spotify.com/v1/tracks/3BXErKHaGALZ...  audio_features
# 1269  https://api.spotify.com/v1/tracks/3nvREfeASA91...  audio_features
# 1021  https://api.spotify.com/v1/tracks/2Jh3UqxnHJMy...  audio_features
# 1075  https://api.spotify.com/v1/tracks/6f6pEjgfTtuR...  audio_features
# 839   https://api.spotify.com/v1/tracks/0HJRAM7Gt9jX...  audio_features
# 871   https://api.spotify.com/v1/tracks/7Hk6vSplBGJ6...  audio_features
# 1024  https://api.spotify.com/v1/tracks/3eekarcy7kvN...  audio_features
# 386   https://api.spotify.com/v1/tracks/3Qeq4pMfjYwX...  audio_features
# 356   https://api.spotify.com/v1/tracks/3lWEqatHZ2wI...  audio_features
# 1683  https://api.spotify.com/v1/tracks/7ixiCZEHWHc8...  audio_features
# 342   https://api.spotify.com/v1/tracks/4YiKrNrLlNQT...  audio_features
# 1663  https://api.spotify.com/v1/tracks/1aEcZKCwqln3...  audio_features
# 275   https://api.spotify.com/v1/tracks/2pfQV8HU5H9R...  audio_features
# 636   https://api.spotify.com/v1/tracks/2jKc6HtnRQTA...  audio_features
# 842   https://api.spotify.com/v1/tracks/3YiUcL1SQzCw...  audio_features
# 980   https://api.spotify.com/v1/tracks/58TaFP5j5i9s...  audio_features
# 1557  https://api.spotify.com/v1/tracks/1u0MZUPQnU9Z...  audio_features
# 1267  https://api.spotify.com/v1/tracks/1zlclNkERGFr...  audio_features
# 2011  https://api.spotify.com/v1/tracks/30lYvwoHHm0N...  audio_features
# 1111  https://api.spotify.com/v1/tracks/5tFpkuwgFZQm...  audio_features
# 1563  https://api.spotify.com/v1/tracks/2zk7TQx9Xa4y...  audio_features
# 1690  https://api.spotify.com/v1/tracks/5WKs5nHNseed...  audio_features
# 1361  https://api.spotify.com/v1/tracks/3R9Nj6ISP8DE...  audio_features
# 1390  https://api.spotify.com/v1/tracks/0TeHvhaNBSuv...  audio_features
# 2163  https://api.spotify.com/v1/tracks/1y5c06C5Zwhc...  audio_features
# 1372  https://api.spotify.com/v1/tracks/4ZReuzjoiFMV...  audio_features
# 1673  https://api.spotify.com/v1/tracks/06ib99OKnjPI...  audio_features
# 1243  https://api.spotify.com/v1/tracks/69xxslCHavbl...  audio_features
# 648   https://api.spotify.com/v1/tracks/2VjiAqbozs3H...  audio_features
# 1482  https://api.spotify.com/v1/tracks/4sy3B9TPNMIz...  audio_features
# 297   https://api.spotify.com/v1/tracks/1VjZA5Wr3GJW...  audio_features
# 1262  https://api.spotify.com/v1/tracks/2NCBjlH7FHEG...  audio_features
# 872   https://api.spotify.com/v1/tracks/0ryEyJ994Sqd...  audio_features
# 865   https://api.spotify.com/v1/tracks/0QwZfbw26QeU...  audio_features
# 894   https://api.spotify.com/v1/tracks/08mG3Y1vljYA...  audio_features
# 870   https://api.spotify.com/v1/tracks/0pKrMTlDlW54...  audio_features
# 1236  https://api.spotify.com/v1/tracks/1CyAxM93XN2a...  audio_features
# 1714  https://api.spotify.com/v1/tracks/6eL1ncVDtQHg...  audio_features
# 260   https://api.spotify.com/v1/tracks/4xyoLXrUb0cp...  audio_features
# 1685  https://api.spotify.com/v1/tracks/2fRoKHW3lzNU...  audio_features
# 1729  https://api.spotify.com/v1/tracks/6bOkaEXc5Cop...  audio_features
# 1457  https://api.spotify.com/v1/tracks/1Vb068SSXLNr...  audio_features
# 909   https://api.spotify.com/v1/tracks/3lPr8ghNDBLc...  audio_features
# 1459  https://api.spotify.com/v1/tracks/0JNRE2AVZvGf...  audio_features
# 309   https://api.spotify.com/v1/tracks/0YBvPvnfflEz...  audio_features
# 315   https://api.spotify.com/v1/tracks/5ooWbs9MGzIg...  audio_features
# 1262  https://api.spotify.com/v1/tracks/2NCBjlH7FHEG...  audio_features
# 879   https://api.spotify.com/v1/tracks/64yrDBpcdwEd...  audio_features
# 1268  https://api.spotify.com/v1/tracks/4NuPdKidxtkT...  audio_features
# 1380  https://api.spotify.com/v1/tracks/0OwdyCX2c7vF...  audio_features
# 1457  spotify:track:1Vb068SSXLNrjQkaNDmEFs   0.4870
# 909   spotify:track:3lPr8ghNDBLc2uZovNyLs9   0.7820
# 1459  spotify:track:0JNRE2AVZvGfJdNNabrVIg   0.4190
# 309   spotify:track:0YBvPvnfflEzgc3GV9vzKA   0.6770
# 315   spotify:track:5ooWbs9MGzIgqzbLoHvAlF   0.1630
# 1262  spotify:track:2NCBjlH7FHEG7hXcnvUaWA   0.4010
# 879   spotify:track:64yrDBpcdwEdNY9loyEGbX   0.4160
# 1268  spotify:track:4NuPdKidxtkTsUN2CdOxUf   0.7760
# 1380  spotify:track:0OwdyCX2c7vFySNR0Um0hY   0.5820

# %% [markdown]
# ### Understanding the Recommendations

# %%
# get list of track IDs from the dataframe
track_list = df_nearest['id'].values

# join the tracks IDs together with commas
tracks_str = ','.join(track_list)

# generate endpoint string
tracks_endpoint = f'https://api.spotify.com/v1/tracks?ids={tracks_str}'

# %%
# request from API
import requests

# NOTE: tokens only last 1 hour. we need a new access token every time we want to run this
access_token = 'BQBspr8U0WrVjL-rSWf7zGQBDTfKq7hkHpA1d9FWaB1j5sCR0n5VhbdaZf9zdAkEXTFL53rEnlwU5nuFzvwi5zvoUBLu_qBLsOa17JK__NmccXiOc_rO5mkrP_GcDfUTj3zSgM8Os2QWVotsnpn-6p5C'

headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json',
    'Accept': 'application/json'
}

req_data = requests.get(tracks_endpoint, headers=headers)

# %%
req_json = req_data.json()

def get_recommendations(req_json):
    """parses response data from Spotify API to get artist names, track names, and URLs
    Args:
        req_json (json): json response data from Spotify API for a set of tracks
    Returns:
        df_recommendations (pd.DataFrame): dataframe of artist names, track names, and URLs 
                                           corresponding to these tracks
    """
    # init a dataframe to hold desired attributes for output
    df_recommendations = pd.DataFrame(columns=['artist name', 'track name', 'URL'])

    # for each track in our response data
    for track in req_json['tracks']:

        # init a series to hold desired attributes for output
        track_series = pd.Series()

        # get artist name
        track_series['artist name'] = track['artists'][0]['name']
        # get track name
        track_series['track name'] = track['name']
        # get track URL
        track_series['URL'] = track['external_urls']['spotify']

        # append our series to the dataframe
        df_recommendations = df_recommendations.append(track_series, ignore_index=True)
        
    return df_recommendations

get_recommendations(req_json)
# Out:
#             artist name                                         track name  \
# 0    The Icarus Account                                      Favorite Girl
# 1          Snarky Puppy                               Bad Kids To The Back
# 2            Juice WRLD                                            Feeling
# 3             Radiohead                                        The Numbers
# 4             Green Day               Holiday / Boulevard of Broken Dreams
# 5        Arctic Monkeys                                   One for the Road
# 6          Travis Scott                                HIGHEST IN THE ROOM
# 7              Lawrence  Do You Want to Do Nothing with Me? - Audiotree...
# 8             Fat Night                                           Question
# 9          Sister Nancy                                            Bam Bam
# 10                Sango                                   Sweet Holy Honey
# 11         Theo Katzman                             You Could Be President
# 12             The Game                                          Stainless
# 13           Blake Ruby                                         Adam & Eve
# 14       Arctic Monkeys                                Still Take You Home
# 15         Travis Scott                                 HOUSTONFORNICATION
# 16       George Clinton                                            To Care
# 27  https://open.spotify.com/track/69xxslCHavbl4EY...
# 28  https://open.spotify.com/track/2VjiAqbozs3HOOk...
# 29  https://open.spotify.com/track/4sy3B9TPNMIze8o...
# 30  https://open.spotify.com/track/1VjZA5Wr3GJWlX7...
# 31  https://open.spotify.com/track/2NCBjlH7FHEG7hX...
# 32  https://open.spotify.com/track/0ryEyJ994SqdJwG...
# 33  https://open.spotify.com/track/0QwZfbw26QeUoIy...
# 34  https://open.spotify.com/track/08mG3Y1vljYA6bv...
# 35  https://open.spotify.com/track/0pKrMTlDlW54abY...
# 36  https://open.spotify.com/track/1CyAxM93XN2atUB...
# 37  https://open.spotify.com/track/6eL1ncVDtQHgSm3...
# 38  https://open.spotify.com/track/4xyoLXrUb0cpROQ...
# 39  https://open.spotify.com/track/2fRoKHW3lzNUKIU...
# 40  https://open.spotify.com/track/6bOkaEXc5CopinG...
# 41  https://open.spotify.com/track/1Vb068SSXLNrjQk...
# 42  https://open.spotify.com/track/3lPr8ghNDBLc2uZ...
# 43  https://open.spotify.com/track/0JNRE2AVZvGfJdN...
# 44  https://open.spotify.com/track/0YBvPvnfflEzgc3...
# 45  https://open.spotify.com/track/5ooWbs9MGzIgqzb...
# 46  https://open.spotify.com/track/2NCBjlH7FHEG7hX...
# 47  https://open.spotify.com/track/64yrDBpcdwEdNY9...
# 48  https://open.spotify.com/track/4NuPdKidxtkTsUN...
# 49  https://open.spotify.com/track/0OwdyCX2c7vFySN...

# %% [markdown]
# ## Are these recommendations good?
# It's difficult to quantify how good song recommendations are, so we'll give a few examples of using specific songs as the query and showing the recommendations that are made for it.

# %% [markdown]
# ```python
# # the endpoint for audio features of Boredom by Tyler the Creator. we found the ID by going
# # in Spotify, clicking the 3 dots next to this song, Share -> Copy Spotify URI
# # here's the result: spotify:track:5WNYg3usc6H8N3MBEp4zVk
# boredom_endpoint = f'https://api.spotify.com/v1/audio-features/5WNYg3usc6H8N3MBEp4zVk'
#
# req_boredom = requests.get(boredom_endpoint, headers=headers)
#
# req_boredom.json()
# ```
# {'danceability': 0.559,
#  'energy': 0.578,
#  'key': 8,
#  'loudness': -9.54,
#  'mode': 1,
#  'speechiness': 0.151,
#  'acousticness': 0.79,
#  'instrumentalness': 0.000522,
#  'liveness': 0.324,
#  'valence': 0.239,
#  'tempo': 79.938,
#  'type': 'audio_features',
#  'id': '5WNYg3usc6H8N3MBEp4zVk',
#  'uri': 'spotify:track:5WNYg3usc6H8N3MBEp4zVk',
#  'track_href': 'https://api.spotify.com/v1/tracks/5WNYg3usc6H8N3MBEp4zVk',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5WNYg3usc6H8N3MBEp4zVk',
#  'duration_ms': 320720,
#  'time_signature': 4}
#
# ```python
# boredom_series = pd.Series(req_boredom.json())
#
# # get the post-PCA values for this song from our data
# df_agg_full.index[df_agg_full['id'] == '5WNYg3usc6H8N3MBEp4zVk']
# # the song is at index 1189, so we can grab it from the post-PCA matrix
# agg_prime[1189]
#
# ```
# array([-1.22901312, -0.04273093, -1.35509872,  0.4443527 , -0.13558097,
#         1.09551314,  0.42465108,  1.58818226, -0.31821814])

# %%
boredom_pca = np.array([-1.22901312, -0.04273093, -1.35509872, 0.4443527 , -0.13558097, 1.09551314, 0.42465108, 1.58818226, -0.31821814])

# use this song as a query to our KDTree, same way we did for the centroids

nearest_boredom = kdt.query(boredom_pca.reshape(-1,1).T, k=10, return_distance=False)

nearest_boredom
# Out:
# array([[ 594,  647,  429, 1535,  423,  929,  280, 2103, 1638,  920]])

# %%
# get the rows from df_agg corresponding to the indices we found
df_nearest = df_agg_full.iloc[nearest_boredom.flatten(), :]

df_nearest
# Out:
#       Unnamed: 0  Unnamed: 0.1  acousticness  \
# 594          594           594      0.585000
# 647          647           647      0.715000
# 429          429           429      0.010600
# 1535         498           498      0.173000
# 423          423           423      0.014400
# 929           92            92      0.000436
# 280          280           280      0.077900
# 2103        1066          1066      0.459000
# 1638         601           601      0.814000
# 920           83            83      0.424000
#
#                                            analysis_url  danceability  \
# 594   https://api.spotify.com/v1/audio-analysis/3gri...         0.782
# 647   https://api.spotify.com/v1/audio-analysis/2bbG...         0.755
# 429   https://api.spotify.com/v1/audio-analysis/1u8B...         0.645
# 1535  https://api.spotify.com/v1/audio-analysis/06PN...         0.897
# 423   https://api.spotify.com/v1/audio-analysis/6Rpu...         0.567
# 929   https://api.spotify.com/v1/audio-analysis/3skn...         0.550
# 280   https://api.spotify.com/v1/audio-analysis/5ri4...         0.771
# 2103  https://api.spotify.com/v1/audio-analysis/4F07...         0.669
# 1638  https://api.spotify.com/v1/audio-analysis/0uk5...         0.773
# 920   https://api.spotify.com/v1/audio-analysis/70dJ...         0.676
#
#       duration_ms  energy                      id  instrumentalness   key  \
# 594      179310.0   0.422  3griMd2FSimhnvHWOveakD          0.000087   5.0
# 647      189284.0   0.520  2bbG9OmvZLCsdWoRu7rj2m          0.000000   3.0
# 429      231571.0   0.705  1u8BiP9APkwKjtVb9L1z50          0.002620   1.0
# 1535     249293.0   0.823  06PNiDGtPIMOq9VU2ftVCk          0.000007   1.0
# 423      266813.0   0.815  6RpunyUP44SDweJPDScLSF          0.000021   8.0
# 929      240213.0   0.874  3skn2lauGk7Dx6bVIt5DVj          0.000010   4.0
# 280      197964.0   0.889  5ri4b7YQp2PWn8tl3MRYgE          0.000065   7.0
# 2103     174867.0   0.735  4F07ku5lMBIoybFPStM2j4          0.000000  10.0
# 1638     210107.0   0.313  0uk5fPe0jKtNG19YRydTyA          0.001850   0.0
# 920      188200.0   0.657  70dJEanFPdYuWZumkrnKeX          0.000147   6.0
#
#       liveness  loudness  mode  speechiness    tempo  time_signature  \
# 594     0.1190    -6.464   0.0       0.3110   87.091             4.0
# 647     0.0956    -5.078   1.0       0.0285   95.047             4.0
# 429     0.1100    -6.400   1.0       0.0443   98.033             4.0
# 1535    0.3310    -6.267   0.0       0.1890  129.056             4.0
# 423     0.1260    -4.915   1.0       0.1410  164.834             4.0
# 929     0.2060    -4.046   1.0       0.0321  121.610             4.0
# 280     0.0426    -7.930   1.0       0.0777  108.015             4.0
# 2103    0.1030    -7.264   1.0       0.3290  117.284             4.0
# 1638    0.1020   -12.263   1.0       0.1340  121.984             4.0
# 920     0.1300    -7.280   1.0       0.0272  105.002             4.0
#
#                                              track_href            type  \
# 594   https://api.spotify.com/v1/tracks/3griMd2FSimh...  audio_features
# 647   https://api.spotify.com/v1/tracks/2bbG9OmvZLCs...  audio_features
# 429   https://api.spotify.com/v1/tracks/1u8BiP9APkwK...  audio_features
# 1535  https://api.spotify.com/v1/tracks/06PNiDGtPIMO...  audio_features
# 423   https://api.spotify.com/v1/tracks/6RpunyUP44SD...  audio_features
# 929   https://api.spotify.com/v1/tracks/3skn2lauGk7D...  audio_features
# 280   https://api.spotify.com/v1/tracks/5ri4b7YQp2PW...  audio_features
# 2103  https://api.spotify.com/v1/tracks/4F07ku5lMBIo...  audio_features
# 1638  https://api.spotify.com/v1/tracks/0uk5fPe0jKtN...  audio_features
# 920   https://api.spotify.com/v1/tracks/70dJEanFPdYu...  audio_features
#
#                                        uri  valence
# 594   spotify:track:3griMd2FSimhnvHWOveakD    0.509
# 647   spotify:track:2bbG9OmvZLCsdWoRu7rj2m    0.517
# 429   spotify:track:1u8BiP9APkwKjtVb9L1z50    0.647
# 1535  spotify:track:06PNiDGtPIMOq9VU2ftVCk    0.767
# 423   spotify:track:6RpunyUP44SDweJPDScLSF    0.325
# 929   spotify:track:3skn2lauGk7Dx6bVIt5DVj    0.318
# 280   spotify:track:5ri4b7YQp2PWn8tl3MRYgE    0.882
# 2103  spotify:track:4F07ku5lMBIoybFPStM2j4    0.723
# 1638  spotify:track:0uk5fPe0jKtNG19YRydTyA    0.698
# 920   spotify:track:70dJEanFPdYuWZumkrnKeX    0.879

# %%
# get list of track IDs from the dataframe
track_list = df_nearest['id'].values

# join the tracks IDs together with commas
tracks_str = ','.join(track_list)

# generate endpoint string
b_tracks_endpoint = f'https://api.spotify.com/v1/tracks?ids={tracks_str}'

b_req_data = requests.get(b_tracks_endpoint, headers=headers)

get_recommendations(b_req_data.json())
# Out:
#          artist name                                         track name  \
# 0       Hablot Brown                                           She Said
# 1    Olivia Willhite                                        Runaway Man
# 2         Cory Henry                                         Happy Days
# 3      Jacob Collier   In My Bones (feat. Kimbra & Tank and The Bangas)
# 4     Anderson .Paak                       Come Home (feat. André 3000)
# 5               Muse                                          Starlight
# 6     Anderson .Paak                                         King James
# 7          NxWorries                                              Suede
# 8      Giorgio Conte                                           Gnè, Gnè
# 9  Charlie Brown Jr.  Ela Vai Voltar (Todos Os Defeitos De Uma Mulhe...
#
#                                                  URL
# 0  https://open.spotify.com/track/3griMd2FSimhnvH...
# 1  https://open.spotify.com/track/2bbG9OmvZLCsdWo...
# 2  https://open.spotify.com/track/1u8BiP9APkwKjtV...
# 3  https://open.spotify.com/track/06PNiDGtPIMOq9V...
# 4  https://open.spotify.com/track/6RpunyUP44SDweJ...
# 5  https://open.spotify.com/track/3skn2lauGk7Dx6b...
# 6  https://open.spotify.com/track/5ri4b7YQp2PWn8t...
# 7  https://open.spotify.com/track/4F07ku5lMBIoybF...
# 8  https://open.spotify.com/track/0uk5fPe0jKtNG19...
# 9  https://open.spotify.com/track/70dJEanFPdYuWZu...
